# %% [markdown]
# Exercise 5: Clustering: k-means and Silhouette, Classification: Evaluation

# %% [markdown]
# Exercise 5-1 Silhouette Coefficient (1 point)
# We derived three different clustering solutions for the toy data set in the lecture:
#
# ![image.png](attachment:image.png)
#
# solution: A, B, C
#
# Compute the simplified silhouette coefficient for each solution. Compare the result with the ranking by the
# k-means objective function (TD2), that we determined in the lecture.

# %%
#simplified silhouette coefficient for solution A

from function_bank.cluster_analysis import *

clusters = [
    [(1,5), (2,3), (3,4), (10,1)],  
    [(7,7), (6,8), (7,8), (7,9)]   
]

print("simplified_silhouette_coefficient")
print(simplified_silhouette_coefficient(clusters, distance_function=euclidean))
print("k_means_objective_function")
print(k_means_objective_function(clusters, distance_function=euclidean))
# Out:
# simplified_silhouette_coefficient
# 0.6937939026296912
# k_means_objective_function
# 61.5

# %%
#simplified silhouette coefficient for solution B

from function_bank.cluster_analysis import *

clusters = [
    [(10,1)],  
    [(7,7), (6,8), (7,8), (7,9), (1,5), (2,3), (3,4),]   
]

print(simplified_silhouette_coefficient(clusters, distance_function=euclidean))
# Out:
# 0.6619596151680767

# %%
#simplified silhouette coefficient for solution C

from function_bank.cluster_analysis import *

clusters = [
    [(1,5), (2,3), (3,4)],  
    [(7,7), (6,8), (7,8), (7,9), (10,1)]   
]

print(simplified_silhouette_coefficient(clusters, distance_function=euclidean))
