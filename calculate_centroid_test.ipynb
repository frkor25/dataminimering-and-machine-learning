# %% [markdown]
# calculate centroide test fra øvelses time 5

# %% [markdown]
# ![Skærmbillede 2026-03-08 kl. 20.59.25.png](<attachment:Skærmbillede 2026-03-08 kl. 20.59.25.png>)

# %%
# 1. centroid (trekant)

from cluster_analysis import *

print(calculate_centroid([(1,5), (2,3), (3,4), (10,1)]))
# Out:
# (4.0, 3.25)

# %%
# 2. centroid (cirkel)

from cluster_analysis import *

print(calculate_centroid([(7,7), (6,8), (7,8), (7,9)]))
# Out:
# (6.75, 8.0)
